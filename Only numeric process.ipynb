# %%
import pandas as pd
import numpy as np

# %%
numeric_columns = pd.read_csv("numeric_data_info_with_integers.csv", index_col=0)

# %%
numeric_columns.shape
# Out:
# (550, 20262)

# %%
numeric_columns
# Out:
#                  ageXatXinitialXpathologicXdiagnosis  gleasonXscore  \
# TCGA-XJ-A83F-01                                   67              7
# TCGA-G9-6348-01                                   68              7
# TCGA-CH-5766-01                                   55              7
# TCGA-EJ-A65G-01                                   57              8
# TCGA-G9-6354-01                                   55              7
# TCGA-EJ-5527-01                                   69              7
# TCGA-HC-8213-01                                   48              6
# TCGA-Y6-A9XI-01                                   72              8
# TCGA-EJ-7125-11                                   44              7
# TCGA-CH-5744-01                                   64              7
# TCGA-EJ-7782-11                                   71              8
# TCGA-HC-A9TE-01                                   64              9
# TCGA-EJ-A7NJ-01                                   59              8
# ...
